# %% [markdown]
# Hello world

# %%
import numpy

# %%
numpy.loadtxt(fname='temperature.csv', delimiter=',')
# Out:
# array([[ 264.,  264.,  264., ...,  263.,  263.,  264.],
#        [ 263.,  264.,  264., ...,  262.,  262.,  263.],
#        [ 301.,  302.,  302., ...,  301.,  301.,  301.],
#        [ 292.,  293.,  293., ...,  291.,  292.,  292.]])

# %%
data = numpy.loadtxt(fname = 'temperature.csv', delimiter =',')

# %%
print data
# Out:
# [[ 264.  264.  264. ...,  263.  263.  264.]
#  [ 263.  264.  264. ...,  262.  262.  263.]
#  [ 301.  302.  302. ...,  301.  301.  301.]
#  [ 292.  293.  293. ...,  291.  292.  292.]]

# %%
print type(data)
# Out:
# <type 'numpy.ndarray'>

# %%
print.shape(data)
# Out:
#   File "<ipython-input-6-bc02a9e0ba20>", line 1
#     print.shape(data)
#          ^
# SyntaxError: invalid syntax

# %%
data[0,0]
# Out:
# 264.0

# %%
data[2,929412343]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-29fb01d369fa> in <module>()
# ----> 1 data[2,929412343]
#
# IndexError: index 929412343 is out of bounds for axis 1 with size 365

# %%
data[0,0:5]
# Out:
# array([ 264.,  264.,  264.,  265.,  265.])

# %%
item =[0,4(data[0,0:5])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-3dce87f5fa03> in <module>()
# ----> 1 item =[0,4(data[0,0:5])]
#
# TypeError: 'int' object is not callable

# %%
data[0:1,-5:]
# Out:
# array([[ 263.,  263.,  263.,  263.,  264.]])

# %%
data[0,-5:]
# Out:
# array([ 263.,  263.,  263.,  263.,  264.])

# %%
data.mean()
# Out:
# 457.83767123287669

# %%
station0 = data[0,:]

# %%
print station0
# Out:
# [ 264.  264.  264.  265.  265.  266.  266.  266.  267.  267.  268.  268.
#   269.  269.  270.  270.  271.  271.  272.  272.  273.  273.  274.  274.
#   275.  276.  276.  277.  278.  278.  279.  280.  281.  281.  282.  283.
#   284.  285.  286.  287.  289.  290.  291.  292.  294.  295.  297.  298.
#   300.  301.  303.  305.  306.  308.  310.  312.  314.  316.  317.  319.
#   321.  323.  325.  327.  329.  331.  333.  335.  337.  339.  341.  343.
#   345.  347.  348.  350.  352.  354.  356.  358.  360.  362.  364.  366.
#   368.  370.  372.  374.  376.  378.  380.  382.  384.  386.  389.  391.
#   393.  395.  398.  400.  402.  405.  407.  410.  412.  415.  417.  420.
#   422.  425.  427.  430.  432.  435.  437.  440.  442.  445.  447.  450.
#   452.  455.  457.  460.  462.  464.  467.  469.  471.  473.  476.  478.
#   480.  482.  484.  486.  488.  490.  493.  495.  497.  499.  501.  503.
#   505.  507.  510.  512.  514.  516.  519.  521.  524.  526.  529.  531.
# ...

# %%
station0.shape
# Out:
# (365L,)

# %%
station0 = station0 / 10

# %%
station0.shape
# Out:
# (365L,)

# %%
station0.max
# Out:
# <function max>

# %%
data = numpy.loadtxt(fname = 'temperature.csv', delimiter =',')

# %%
data = data / 10

# %%
shape.data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-853fa2760c28> in <module>()
# ----> 1 shape.data
#
# NameError: name 'shape' is not defined

# %%
data.shape
# Out:
# (4L, 365L)

# %%
station0 = data[0,:]

# %%
data.shape
# Out:
# (4L, 365L)

# %%
element = 'oxygen'

# %%
print 'first three characters:', element[0:3]
# Out:
# first three characters: oxy

# %%
print 'last three characters:', element[3:6]
# Out:
# last three characters: gen

# %%
print element[1:-1]
# Out:
# xyge

# %%
print element[1:-1]
# Out:
# xyge

# %%
print element[1:-1]
# Out:
# xyge

# %%
cprint element[1:-1]
# Out:
# xyge

# %%
data.max
# Out:
# <function max>

# %%
data.max(axis=1)
# Out:
# array([ 64.1,  62.4,  71.4,  66.6])

# %%
import matplotlib
# %matplotlib inline

# %%
matplotlib.pyplot.imshow(data)

# %%
matplotlib.pyplot.imshow(data)
matplotlib.pyplot.axes().set_aspect('auto')

# %%
ave_temp = data.mean(axis = 0)
matplotlib.pyplot.plot(ave_temp)

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
data = np.loadtxt(fname = 'temperature.csv', delimiter = ',')

# %%
print(data)
# Out:
# [[ 264.  264.  264. ...,  263.  263.  264.]
#  [ 263.  264.  264. ...,  262.  262.  263.]
#  [ 301.  302.  302. ...,  301.  301.  301.]
#  [ 292.  293.  293. ...,  291.  292.  292.]]

# %%
fig = plt.figure(figsize = (5., 9.))

# %%
axesl = fig.add_subplot(4,1,1)
axesl = fig.add_subplot(4,1,2)
axesl = fig.add_subplot(4,1,3)
axesl = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1])
axes3.plot(data[2:])
axes4.plot(data[3:])

plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-4a845efb5652> in <module>()
#       4 axesl = fig.add_subplot(4,1,4)
#       5
# ----> 6 axes1.plot(data[0,:])
#       7 axes2.plot(data[1:])
#       8 axes3.plot(data[2:])
#
# NameError: name 'axes1' is not defined

# %%
axesl = fig.add_subplot(4,1,1)
axesl = fig.add_subplot(4,1,2)
axesl = fig.add_subplot(4,1,3)
axesl = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-7dd797a82278> in <module>()
#       4 axesl = fig.add_subplot(4,1,4)
#       5
# ----> 6 axes1.plot(data[0,:])
#       7 axes2.plot(data[1,:])
#       8 axes3.plot(data[2,:])
#
# NameError: name 'axes1' is not defined

# %%
axesl = fig.add_subplot(4,1,1)
axes2 = fig.add_subplot(4,1,2)
axes3 = fig.add_subplot(4,1,3)
axes4 = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-385b298a8d2d> in <module>()
#       4 axes4 = fig.add_subplot(4,1,4)
#       5
# ----> 6 axes1.plot(data[0,:])
#       7 axes2.plot(data[1,:])
#       8 axes3.plot(data[2,:])
#
# NameError: name 'axes1' is not defined

# %%
axes1 = fig.add_subplot(4,1,1)
axes2 = fig.add_subplot(4,1,2)
axes3 = fig.add_subplot(4,1,3)
axes4 = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
axes1 = fig.add_subplot(4,1,1)
axes2 = fig.add_subplot(4,1,2)
axes3 = fig.add_subplot(4,1,3)
axes4 = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (5., 9.))

# %%
axes1 = fig.add_subplot(4,1,1)
axes2 = fig.add_subplot(4,1,2)
axes3 = fig.add_subplot(4,1,3)
axes4 = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (5., 9.))

axes1 = fig.add_subplot(4,1,1)
axes2 = fig.add_subplot(4,1,2)
axes3 = fig.add_subplot(4,1,3)
axes4 = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
axes1 = fig.add_subplot(4,1,1)
axes2 = fig.add_subplot(4,1,2)
axes3 = fig.add_subplot(4,1,3)
axes4 = fig.add_subplot(4,1,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
axes1 = fig.add_subplot(4,1,1)
axes2 = fig.add_subplot(4,1,2)
axes3 = fig.add_subplot(4,1,3)
axes4 = fig.add_subplot(4,1,4)

axes1.plot(numpy.max(data[0,:]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (5., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.max(data[0,:]))
axes2.plot(numpy.max(data[1,:]))
axes3.plot(numpy.max(data[2,:]))
axes4.plot(numpy.max(data[3,:]))

plt.show(fig)

# %%
fig = plt.figure(figsize = (5., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.max(data[0,:]))
axes2.plot(numpy.max(data[1,:]))
axes3.plot(numpy.max(data[2,:]))
axes4.plot(numpy.max(data[3,:]))

plt.show(fig)

matplotlib.pyplot.axes().set_aspect('auto')

# %%
fig = plt.figure(figsize = (5., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(data[0,:])
axes2.plot((data[1,:])
axes3.plot((data[2,:]))
axes4.plot((data[3,:]))

plt.show(fig)
# Out:
#   File "<ipython-input-54-4b738359ad1b>", line 10
#     axes3.plot((data[2,:]))
#         ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(figsize = (5., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (5., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(np.min(data[0,:])
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)
# Out:
#   File "<ipython-input-57-3fdfbc9b5816>", line 9
#     axes2.plot(data[1,:])
#         ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(figsize = (5., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[0,:]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[0,:]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[0,0:4]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[:,0]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
data = data / 10

# %%
fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[:,0]))
axes2.plot(data[1,:])fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[:,0]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
numpy.min(data[:,:])
# Out:
# 26.100000000000001

# %%
numpy.min(data[1,:])
# Out:
# 26.100000000000001

# %%
numpy.min(data[:,0
              ])
# Out:
# 26.300000000000001

# %%
numpy.min(data[:,1
              ])
# Out:
# 26.399999999999999

# %%
fig = plt.figure(figsize = (9., 9.))

axes2.plot(data[1,:])fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[:,0]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)
# Out:
#   File "<ipython-input-68-4942a26df711>", line 3
#     axes2.plot(data[1,:])fig = plt.figure(figsize = (9., 9.))
#                            ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(numpy.min(data[:,0]))
axes2.plot(data[1,:])
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)
axes3.plot(data[2,:])
axes4.plot(data[3,:])

plt.show(fig)

# %%
fig = plt.figure(figsize = (9., 9.))

axes1 = fig.add_subplot(3,1,1)
axes2 = fig.add_subplot(3,1,2)
axes3 = fig.add_subplot(3,1,3)


axes1.set_ylabel('max')
axes1.plot(data.max(axis=0))

axes2.set_ylabel('min')
axes2.plot(data.min(axis=0))  
           
axes3.set_ylabel('stdev')
axes3.plot(data.std(axis=0))

plt.show(fig)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-8566f15a9b17> in <module>()
# ----> 1 pp = PdfPages('foo.pdf')
#       2 pp.savefig(plot1)
#       3 pp.savefig(plot2)
#       4 pp.savefig(plot3)
#       5 pp.close()
#
# NameError: name 'PdfPages' is not defined

# %%
pp = PdfPages('foo.pdf')
pp.savefig(axes1)
pp.savefig(axes2
pp.savefig(axes3
pp.close()
# Out:
#   File "<ipython-input-73-48b612e4c66f>", line 4
#     pp.savefig(axes3
#      ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as pp
pp = PdfPages('foo.pdf')
pp.savefig(plot1)
pp.savefig(plot2)
pp.savefig(plot3)
pp.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-37200e1d1858> in <module>()
#       1 import matplotlib.pyplot as pp
# ----> 2 pp = PdfPages('foo.pdf')
#       3 pp.savefig(plot1)
#       4 pp.savefig(plot2)
#       5 pp.savefig(plot3)
#
# NameError: name 'PdfPages' is not defined

# %%
from matplotlib.backends.backend_pdf import PdfPages

pp = PdfPages('foo.pdf')
pp.savefig(plot1)
pp.savefig(plot2)
pp.savefig(plot3)
pp.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-722a105bf118> in <module>()
#       2
#       3 pp = PdfPages('foo.pdf')
# ----> 4 pp.savefig(plot1)
#       5 pp.savefig(plot2)
#       6 pp.savefig(plot3)
#
# NameError: name 'plot1' is not defined

# %% [raw]
# from matplotlib.backends.backend_pdf import PdfPages
#
# pp = PdfPages('foo.pdf')
# pp.savefig(axes1)
# pp.close()

# %%
odds = [1, 3, 5, 9]

# %%
print.odds
# Out:
#   File "<ipython-input-78-118ef4bd47ec>", line 1
#     print.odds
#          ^
# SyntaxError: invalid syntax

# %%
print(odds)
# Out:
# [1, 3, 5, 9]

# %%
odds.append(11)

# %%
print(odds)
# Out:
# [1, 3, 5, 9, 11]

# %%
print(odds)
# Out:
# [1, 3, 5, 9, 11]

# %%
word = 'oxygen'

# %%
for item in word:
    print item
# Out:
# o
# x
# y
# g
# e
# n

# %%
length = 0

for letter in word:
    length = length + 1
    
print length
# Out:
# 6

# %%
[85]
# Out:
# [85]

# %%
In[85]
# Out:
# u'length = 0\n\nfor letter in word:\n    length = length + 1\n    \nprint length'

# %%
print(word)
# Out:
# oxygen

# %%
len(word)
# Out:
# 6

# %%
number = 5

# %%
power = 3

# %%
len(power)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-b860ed7c1c77> in <module>()
# ----> 1 len(power)
#
# TypeError: object of type 'int' has no len()

# %%
loop = [1, 2]

# %%
loop
# Out:
# [1, 2]

# %%
len(loop)
# Out:
# 2

# %%
for item in loop
    5 * 5
# Out:
#   File "<ipython-input-99-92f834af65a9>", line 1
#     for item in loop
#                     ^
# SyntaxError: invalid syntax

# %%
for item in loop:
    5 * 5

# %%
value = 5

# %%
for item in loop
    value * item
print(value
         
     )
# Out:
#   File "<ipython-input-102-e4efe7c022af>", line 1
#     for item in loop
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# print 5**3

# %%
print 5**3
# Out:
# 125

# %%
5*5
# Out:
# 25

# %%
5*5*5
# Out:
# 125

# %%
length = abc
for len(length)
l    5**len(length)
# Out:
#   File "<ipython-input-107-5de585e2b8f4>", line 2
#     for len(length)
#                    ^
# SyntaxError: invalid syntax

# %%
list = [5,5,5]
var = 5
for item in list:
    var = var*item
    print(var)
# Out:
# 25
# 125
# 625

# %%
list = [5,5]
var = 5
for item in list:
    var = var*item
    print(var)
# Out:
# 25
# 125

# %%
num = 110

if num > 100:
    print 'greater'
elif num == 100:
    print 'equal'
else:
     print 'not greater'
print 'done'
# Out:
# greater
# done

# %%
if True:
     print 'True is true'
if False:
     print 'False is false'
if '':
    print 'empty string is true'
if 'word':
    print 'word is true'
if []:
    print 'empty list is true'
if [1, 2, 3]:
    print 'non-empty list is true'
if 0:
    print 'zero is true'
if 1:
    print 'one is true'
# Out:
# True is true
# word is true
# non-empty list is true
# one is true

# %%
if 0:
    print 'zero is true'

# %%
import random

# %%
randomnumbers= []

for i in range(100):
    randomnumbers.append(random.randint(-10,10))
    
print len(randomnumbers)
# Out:
# 100

# %% [raw]
# print(randomnumbers)

# %%
print randombumbers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-f8d29944af6e> in <module>()
# ----> 1 print randombumbers
#
# NameError: name 'randombumbers' is not defined

# %%
print randomnumbers
# Out:
# [3, 9, -3, 3, 10, -9, -2, 4, -5, -4, -5, -4, -1, -4, 9, 4, 8, -4, 9, 9, 5, 5, 5, -6, 9, 0, 4, 7, 2, 8, -4, 10, -1, 2, 5, -8, 2, 6, 10, -4, -4, 4, 5, -2, -8, 8, -4, 10, 8, 5, 3, 9, -3, -9, -3, 7, 8, -5, -9, -5, -5, 1, 3, -9, -5, -10, -2, 3, 3, -2, 7, -5, 3, 0, -8, -8, 4, -4, 4, 5, -9, -2, -1, -2, 5, -2, 1, -5, 9, -9, 7, -6, -5, 3, 3, 2, -10, 5, -2, 10]

# %%
sumpositives = 0
sumnegatives = 0

for num in randomnumbers:
    if num < 0:
        sumnegatives = sumnegatives + num
    else:
        sumpositives = sumpositives + num

print sumpositives, sumnegatives
# Out:
# 293 -227

# %%
data['Station'] = '09163500'
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-5d009e44dbfa> in <module>()
# ----> 1 data['Station'] = '09163500'
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-d53040d906fa> in <module>()
# ----> 1 data.dtypes
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dtypes'
